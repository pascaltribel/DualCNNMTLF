# %% [markdown]
# # Belgian Load Forecasting
# Gian Marco PALDINO, Pascal TRIBEL
# ## 1. Preprocessing

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd
import scipy
from datetime import datetime

# %% [markdown]
# ### Data reading

# %%
filepath = "./ods001.csv"
data = pd.read_csv(filepath, delimiter=";")[::-1].reset_index().drop("index", axis=1)

# %% [markdown]
# The data is sampled with a temporal granularity of 15 minutes: the resolution code column does not bring additionnal information. We discard it:

# %%
data = data.drop(columns = ["Resolution code"])

# %% [markdown]
# We process the timestamps. The datetime is set to `UTC+0` values, and the year, month, day, hour, minutes and season is extracted from the timestamps:

# %%
data["Datetime"] = pd.to_datetime(data["Datetime"], errors='coerce', utc=True)
data["Datetime"] = data["Datetime"].dt.tz_convert("UTC")
data["Year"] = [i.year for i in data["Datetime"]]
data["Month"] = [i.month for i in data["Datetime"]]
data["Day"] = [i.day for i in data["Datetime"]]
data["Hour"] = [i.hour for i in data["Datetime"]]
data["Minute"] = [i.minute for i in data["Datetime"]]
data["Season"] = data["Month"]//4

# %% [markdown]
# Belgium has experienced the COVID lockdown:
# - Between the 18/3/2020 and the 3/5/2020
# - Between the 2/11/2020 and the 1/4/2021
#
# <a href="https://fr.wikipedia.org/wiki/Pandémie_de_Covid-19_en_Belgique">Wikipedia page of the Belgian COVID crisis</a>

# %%
data["Lockdown"] = 0
data.loc[182692:187181, "Lockdown"] = 1
data.loc[204772:219268, "Lockdown"] = 1

# %% [markdown]
# We interpolate linearly the Total Load to impute missing values:

# %%
data['Total Load Interpolated'] = data['Total Load'].interpolate(method='linear')

# %%
data.head()
# Out:
#                    Datetime  Total Load  Most recent forecast  \
# 0 2014-12-31 23:00:00+00:00    10142.19               9496.05
# 1 2014-12-31 23:15:00+00:00    10051.28               9329.17
# 2 2014-12-31 23:30:00+00:00     9952.87               9174.72
# 3 2014-12-31 23:45:00+00:00     9821.78               9025.46
# 4 2015-01-01 00:00:00+00:00     9755.00               9222.33
#
#    Most recent P10  Most recent P90  Day-ahead 6PM forecast  \
# 0          8871.71         10120.38                 9697.59
# 1          8715.80          9942.53                 9526.54
# 2          8571.51          9777.92                 9367.66
# 3          8432.07          9618.85                 9216.09
# 4          8880.23          9564.44                10130.36
#
#    Day-ahead 6PM P10  Day-ahead 6PM P90  Week-ahead forecast  Year  Month  \
# 0            9076.64           10318.53              9833.37  2014     12
# 1            8916.55           10136.53              9653.31  2014     12
# 2            8767.84            9967.47              9473.22  2014     12
# 3            8625.97            9806.20              9319.45  2014     12
# 4            9777.87           10482.86              9203.25  2015      1
#
#    Day  Hour  Minute  Season  Lockdown  Total Load Interpolated
# 0   31    23       0       3         0                 10142.19
# 1   31    23      15       3         0                 10051.28
# 2   31    23      30       3         0                  9952.87
# 3   31    23      45       3         0                  9821.78
# 4    1     0       0       0         0                  9755.00

# %% [markdown]
# We define the mean absolute percentage error as
# \begin{equation}
#     MAPE(y, \hat{y}) = \frac{100}{n}\sum^n\frac{y-\hat{y}}{y}
# \end{equation}

# %%
def mape(y_true, y_pred):
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

# %% [markdown]
# Here is an example of the most recent forecasting provided by ELIA, compared to the ground truth:

# %%
plt.figure(figsize=(10, 6))
plt.plot(data["Datetime"][11000:11500], data["Total Load"][11000:11500], label="Total Load")
plt.plot(data["Datetime"][11000:11500], data["Most recent forecast"][11000:11500], label="Most recent forecast")
plt.title(f"ELIA Forecasting example\nMAPE: {mape(data['Total Load'][11000:11500], data['Most recent forecast'][11000:11500]):.4f}%")
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# We save the data to a csv:

# %%
data.to_csv("preprocessed_data.csv")
